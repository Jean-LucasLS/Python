# %%
import pandas as pd

df1 = pd.DataFrame(
  {
    'Key': ['K0', 'K1', 'K2', 'K3'],
    'A'  : ['A0', 'A1', 'A2', 'A3'],
    'B'  : ['B0', 'B1', 'B2', 'B3']
  }, index=range(4)
)

df2 = pd.DataFrame(
  {
    'Key': ['K1', 'K2', 'K3', 'K4'],
    'C'  : ['C1', 'C2', 'C3', 'C4'],
    'D'  : ['D1', 'D2', 'D3', 'D4']
  }, index=range(1,5)
)

# %%
from IPython.display import display_html

def display_side_by_side(dataframes:list, titles:list):
  html_str=''
  for df, title in zip(dataframes, titles):
    html_str+=f'<span>{title}:</span>'
    html_str+=df.to_html().replace('table', 'table style="display:inline"')
    html_str+='&nbsp'*10
  display_html(html_str,raw=True)

# %%
display_side_by_side([df1, df2], ['df1', 'df2'])
# Out:
# <span>df1:</span><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Key</th>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>K0</td>
#       <td>A0</td>
#       <td>B0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>K1</td>
#       <td>A1</td>
#       <td>B1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>K2</td>
#       <td>A2</td>
#       <td>B2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>K3</td>
#       <td>A3</td>
#       <td>B3</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp<span>df2:</span><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Key</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>K1</td>
#       <td>C1</td>
#       <td>D1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>K2</td>
#       <td>C2</td>
#       <td>D2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>K3</td>
#       <td>C3</td>
#       <td>D3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>K4</td>
#       <td>C4</td>
#       <td>D4</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp

# %%
df_inner = df1.merge(df2, on='Key', how='inner')
df_left  = df1.merge(df2, on='Key', how='left' )
df_right = df1.merge(df2, on='Key', how='right')

all_dfs    = [ df1,   df2,   df_inner,   df_left,   df_right ]
# all_titles = ['df1', 'df2', 'df_inner', 'df_left', 'df_right']

import itertools

# Convert a list of variables to the corresponding names as strings 
def get_variable_name(var_value, namespace):
    return [name for name, value in namespace.items() if value is var_value]

all_titles = list(itertools.chain(*[get_variable_name(item, globals()) for item in all_dfs]))

print(all_titles)

display_side_by_side(all_dfs, all_titles)
# Out:
# ['df1', 'df2', 'df_inner', 'df_left', 'df_right']
# <span>df1:</span><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Key</th>
#       <th>A</th>
#       <th>B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>K0</td>
#       <td>A0</td>
#       <td>B0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>K1</td>
#       <td>A1</td>
#       <td>B1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>K2</td>
#       <td>A2</td>
#       <td>B2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>K3</td>
#       <td>A3</td>
#       <td>B3</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp<span>df2:</span><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Key</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>K1</td>
#       <td>C1</td>
#       <td>D1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>K2</td>
#       <td>C2</td>
#       <td>D2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>K3</td>
#       <td>C3</td>
#       <td>D3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>K4</td>
#       <td>C4</td>
#       <td>D4</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp<span>df_inner:</span><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Key</th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>K1</td>
#       <td>A1</td>
#       <td>B1</td>
#       <td>C1</td>
#       <td>D1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>K2</td>
#       <td>A2</td>
#       <td>B2</td>
#       <td>C2</td>
#       <td>D2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>K3</td>
#       <td>A3</td>
#       <td>B3</td>
#       <td>C3</td>
#       <td>D3</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp<span>df_left:</span><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Key</th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>K0</td>
#       <td>A0</td>
#       <td>B0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>K1</td>
#       <td>A1</td>
#       <td>B1</td>
#       <td>C1</td>
#       <td>D1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>K2</td>
#       <td>A2</td>
#       <td>B2</td>
#       <td>C2</td>
#       <td>D2</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>K3</td>
#       <td>A3</td>
#       <td>B3</td>
#       <td>C3</td>
#       <td>D3</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp<span>df_right:</span><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Key</th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>K1</td>
#       <td>A1</td>
#       <td>B1</td>
#       <td>C1</td>
#       <td>D1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>K2</td>
#       <td>A2</td>
#       <td>B2</td>
#       <td>C2</td>
#       <td>D2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>K3</td>
#       <td>A3</td>
#       <td>B3</td>
#       <td>C3</td>
#       <td>D3</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>K4</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>C4</td>
#       <td>D4</td>
#     </tr>
#   </tbody>
# </table style="display:inline">&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp&nbsp

# %%
from ipywidgets import interact

@interact(method=['inner', 'left', 'right', 'outer'])
def merge(method):
  df_merge   = df1.merge(df2, how=method)
  all_dfs    = [ df1,   df2,      df_merge    ]
  all_titles = ['df1', 'df2', f'{method}_join']
  display_side_by_side(all_dfs, all_titles)
  
#merge(df1, df2, method='right')
# Out:
# interactive(children=(Dropdown(description='method', options=('inner', 'left', 'right', 'outer'), value='inner…
